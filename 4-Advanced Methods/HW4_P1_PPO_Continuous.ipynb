# %%
# %%capture
# !pip install mujoco==2.3.3

# %% [markdown]
# Ayeen Poostforoushan
# 401105742

# %% [markdown]
# ## **Importing Required Libraries**
#
# This cell imports all the necessary libraries for implementing **Proximal Policy Optimization (PPO)**. The key components include:

# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical
from torch.distributions import MultivariateNormal
import torch.nn.functional as F

import torch.optim as optim
import gymnasium as gym
import numpy as np
import os
import pandas as pd

import imageio
from base64 import b64encode
from IPython.display import HTML


import logging
import matplotlib
import matplotlib.pyplot as plt
is_ipython = 'inline' in matplotlib.get_backend()
import numpy as np

if is_ipython:
    from IPython import display

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## **Logging, Visualization, and Video Playback Functions**

# %%
logging.getLogger().setLevel(logging.ERROR)

# set up matplotlib
plt.ion()
plt.xkcd(scale=1, length=100, randomness=2)
matplotlib.rcParams['figure.figsize'] = (12, 6)


def plot_rewards(sum_of_rewards, show_result=None , bove = None,dn = None):
    plt.figure(1)
    rewards = torch.tensor(sum_of_rewards, dtype=torch.float)
    if show_result is not None:
        plt.title(f'{show_result}')
    else:
        plt.clf()
        plt.title('Training...')
    if bove is not None:
        plt.xlabel(f'{bove}')
    else:
        plt.xlabel('Episode')
    if dn is not None:
        plt.xlabel(f'{dn}')
    else:
        plt.ylabel('Reward')
    plt.plot(rewards.numpy())
    # Take 50 episode averages and plot them too
    length = len(rewards)
    init_len = min(49, length)
    init_means = np.cumsum(rewards[:init_len]) / (1 + np.arange(init_len))
    if length > 50:
        means = rewards.unfold(0, 50, 1).mean(1).view(-1)
        means = torch.cat((init_means, means))
    else:
        means = init_means
    plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())

def show_video(path):
    mp4 = open(path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width=400 controls>
          <source src="%s" type="video/mp4">
    </video>
    """ % data_url)

# %% [markdown]
# ## **Memory Buffer for PPO**
#
# ### **Class: `Memory`**
# - A **buffer** for storing experiences during training, used for **PPO (Proximal Policy Optimization) updates**.
# - Stores the following per episode:
#   - `actions`: Actions taken by the agent.
#   - `states`: Observed states from the environment.
#   - `logprobs`: Log probabilities of actions (needed for importance sampling in PPO).
#   - `rewards`: Rewards obtained after taking actions.
#   - `state_values`: Estimated state values from the critic.
#
# ### **Function: `clear()`**
# - Clears the stored experiences before collecting new trajectories.
# - Ensures memory is reset between updates to prevent stale data from affecting optimization.

# %%
class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.state_values = []

    def clear(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.state_values[:]

# %% [markdown]
# ## **Actor-Critic Network in PPO**
#
# This implementation defines two neural networks used in Proximal Policy Optimization (PPO).
#
# The actor network is responsible for predicting a probability distribution over actions (discrete) or estimating the value for each action (continuous), given the current state, while the critic network evaluates how good the action taken by the actor is, by predicting the reward based on state.

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, hidden_size, action_dim):
        super(Actor, self).__init__()
        self.FC = nn.Sequential(
            nn.Linear(state_dim, hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, action_dim),
            nn.Tanh(),
            )

        self.logstd = nn.Parameter(torch.zeros(action_dim), requires_grad=True)


    def forward(self, state):
        mu = self.FC(state)
        std = torch.exp(self.logstd)
        return mu, std

class Critic(nn.Module):
    def __init__(self, state_dim, hidden_size):
        super(Critic, self).__init__()
        self.FC = nn.Sequential(
            nn.Linear(state_dim, hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, 1),
            )

    def forward(self, state):
        value = self.FC(state)
        return value

# %% [markdown]
# ## **Proximal Policy Optimization (PPO) Algorithm Implementation**
#
# This class implements the **PPO (Proximal Policy Optimization) algorithm**, which is a policy gradient method used in reinforcement learning. It optimizes an actor-critic network while maintaining stability and efficiency.
#
# ### **Key Components:**
# 1. **Initialization (`__init__`)**:
#    - Sets hyperparameters (e.g., `gamma`, `eps_clip`, `gae_lambda`).
#    - Creates **Actor and Critic networks**.
#    - Defines **Adam optimizers** for both networks.
#    - Initializes a memory buffer for storing experience.
#
# 2. **Action Selection (`select_action`)**:
#    - Uses the **Actor network** to predict a mean and standard deviation for the action.
#    - Samples an action from a normal distribution.
#    - Stores the action, log probability, and value function output in memory.
#
# 3. **Policy Evaluation (`evaluate`)**:
#    - Computes the log probability of actions under the current policy.
#    - Returns entropy (used for exploration encouragement).
#
# 4. **Policy Update (`update`)**:
#    - Computes **discounted rewards** and **Generalized Advantage Estimation (GAE)**.
#    - Uses **clipped surrogate objective** to stabilize training.
#    - Minimizes **actor loss** (policy update) and **critic loss** (value function update).
#    - Updates networks using **gradient descent**.
#
# 5. **Memory Handling (`push_memory`, `load_memory`, `store_reward`)**:
#    - Stores and retrieves experience for training updates.
#    - Resets the memory buffer after each policy update.
#
# ### **Key Features of PPO**
# - **Clipping Ratio**: Prevents excessive updates to the policy, improving stability.
# - **Advantage Estimation**: Helps in reducing variance in policy updates.
# - **Entropy Regularization**: Encourages exploration by adding entropy loss.

# %% [markdown]
# ## **1. PPO Clipped Loss Function**
# The PPO loss function prevents large policy updates by introducing a clipped objective. The ratio of new and old policy probabilities is computed as:
# $$
# r_t(\theta) = \frac{\pi_{\theta}(a_t | s_t)}{\pi_{\theta_{\text{old}}}(a_t | s_t)}
# $$
# where:
# - $ \theta $ are the current policy parameters.
# - $\theta_{\text{old}} $ are the policy parameters before the update.
#
# The surrogate loss function is:
# $$
# L^{\text{CLIP}}(\theta) = \mathbb{E} \left[ \min \left( r_t(\theta) A_t, \text{clip}(r_t(\theta), 1 - \epsilon, 1 + \epsilon) A_t \right) \right]
# $$
# where:
# - $ A_t $ is the **advantage function**, which measures how much better an action is compared to the expected value of the state.
# - $ \epsilon $ is a small clipping parameter (e.g., **0.2**) that prevents drastic policy updates.
#
# ---
#
# ## **2. Critic Loss Function**
# The critic is updated using **Mean Squared Error (MSE)** between the predicted and actual state value:
# $$
# L_{\text{critic}} = \mathbb{E} \left[ (V(s_t) - R_t)^2 \right]
# $$
#
# ---
#
# ## **3. Total Loss**
# The overall loss function is:
# $$
# L_{\text{total}} = L^{\text{CLIP}} + \beta H - L_{\text{critic}}
# $$
# where:
# - $ H $ is the **entropy bonus** to encourage exploration.
# - $ \beta $ is a small coefficient (e.g., **0.01**) controlling the strength of the entropy bonus.

# %%
class PPO(nn.Module):
    def __init__(self, env, config):
        super(PPO, self).__init__()
        self.gamma = config.GAMMA
        self.eps_clip = config.EPS_CLIP
        self.epochs = config.K_EPOCHS
        self.gae_lambda = config.GAE
        self.hidden_size = config.hidden_size

        self.lr = config.LEARNING_RATE
        state_dim = env.observation_space.shape[0]
        action_dim = env.action_space.shape[0]

        self.actor = Actor(state_dim, self.hidden_size, action_dim).to(device)
        self.critic = Critic(state_dim, self.hidden_size).to(device)

        self.optimizer_actor = optim.Adam(self.actor.parameters(), lr=self.lr)
        self.optimizer_critic = optim.Adam(self.critic.parameters(), lr=self.lr)
        self.memory = Memory()

    def select_action(self, state):
        # Save state, action, log probability and state value of current step in the memory buffer.
        # predict the actions by sampling from a normal distribution
        # based on the mean and std calculated by actor
        state = torch.tensor(state, dtype=torch.float32).to(device)
        with torch.no_grad():
            mu, std = self.actor(state)
            cov_mat = torch.diag(std**2).to(device)
            dist = MultivariateNormal(mu, covariance_matrix=cov_mat)
            action = dist.sample()
            action_logprobs = dist.log_prob(action)
            state_value = self.critic(state)

        self.push_memory(state, action, action_logprobs, state_value)

        return action.squeeze(0).cpu().numpy()

    def evaluate(self, state, action):
        # evaluate the state value of this state and log probability of choosing this action
        mu, std = self.actor(state)
        dist = MultivariateNormal(mu, covariance_matrix=torch.diag(std**2).to(device))
        action_logprobs = dist.log_prob(action)
        entropy = dist.entropy()
        state_value = self.critic(state).squeeze()
        return action_logprobs, state_value, entropy

    def update(self):
        rewards = torch.tensor(self.memory.rewards, dtype=torch.float32).to(device)

        # load saved states, actions, log probs, and state values
        old_states, old_actions, old_logprobs, old_state_vals = self.load_memory()

        # discounted_reward = 0
        # for i in reversed(range(len(rewards))):
        #     if i == len(rewards) - 1:
        #         discounted_reward = rewards[i]
        #     else:
        #         discounted_reward = rewards[i] + self.gamma * discounted_reward
        #     rewards[i] = discounted_reward

        advantages = []
        gae = 0
        # Calculate gae for each timestep
        for i in reversed(range(len(rewards))):
            # calculate the discounted reward
            if i == len(rewards) - 1:
                next_state_value = 0
            else:
                next_state_value = old_state_vals[i + 1]
            delta = rewards[i] + self.gamma * next_state_value - old_state_vals[i]
            gae = (self.gae_lambda * self.gamma) * gae + delta
            advantages.insert(0, gae)

        advantages = torch.tensor(advantages, dtype=torch.float32, device=device).detach()
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        returns = advantages + old_state_vals


        loss_ac = 0
        loss_cri = 0
        for _ in range(self.epochs):
            # calculate logprobs and state values based on the new policy
            new_logprobs, state_vals, entropy = self.evaluate(old_states, old_actions)

            # Calculate the loss function and perform the optimization
            prob_ratios = torch.exp(new_logprobs - old_logprobs.detach())

            loss_opt1 = prob_ratios * advantages
            loss_opt2 = torch.clamp(prob_ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages

            loss_actor = -torch.min(loss_opt1, loss_opt2) - 0.01 * entropy
            loss_actor = loss_actor.mean()

            loss_ac += loss_actor.item()

            state_vals = state_vals.squeeze()
            # print(f"state_vals size: {state_vals.size()}, rewards size: {rewards.size()}")
            loss_critic = (state_vals - returns).pow(2)
            loss_critic = loss_critic.mean()

            loss_cri += loss_critic.item()
            loss_ac += loss_actor.item()

            self.optimizer_actor.zero_grad()
            loss_actor.backward(retain_graph=True)
            self.optimizer_actor.step()

            self.optimizer_critic.zero_grad()
            loss_critic.backward()
            self.optimizer_critic.step()

        # clear the buffer
        self.memory.clear()
        return loss_ac, loss_cri

    def push_memory(self,state, action, log_prob, value ):
        self.memory.states.append(state)
        self.memory.actions.append(action)
        self.memory.logprobs.append(log_prob)
        self.memory.state_values.append(value)

    def load_memory(self):
        old_states = torch.stack(self.memory.states).detach()
        old_actions = torch.stack(self.memory.actions).detach()
        old_logprobs = torch.stack(self.memory.logprobs).detach()
        old_state_vals = torch.stack(self.memory.state_values).detach()

        return old_states, old_actions, old_logprobs, old_state_vals

    def store_reward(self, reward):
      self.memory.rewards.append(reward)

# %% [markdown]
# ## **Configuration Settings for PPO Training**
#
# The `Config` class defines **hyperparameters and settings** for training the PPO agent in a reinforcement learning environment.

# %%
class Config:
    # Environment settings
    SEED = 111
    MAX_EPISODES = 3000


    # PPO Hyperparameters
    K_EPOCHS = 5
    EPS_CLIP = 0.2
    GAMMA = 0.99
    LEARNING_RATE = 0.0008
    BETAS = (0.9, 0.99)

    hidden_size= 64
    GAE = 0.96

    DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # **Proximal Policy Optimization (PPO) Training on HalfCheetah-v4 Environment**
#
# This notebook implements and trains a **Proximal Policy Optimization (PPO)** agent on the **HalfCheetah-v4** environment. The PPO algorithm is an on-policy reinforcement learning method that uses a clipped objective function to update the policy in a stable way.

# %%
env = gym.make("HalfCheetah-v4")
config = Config()

agent  = PPO(env, config)

# We need to train for many more steps to achieve acceptable results compared to the last environment
actor_losses = []
critic_losses = []
rewards_history = []
sum_of_rewards = []
for episode in range(config.MAX_EPISODES):
    state, _ = env.reset()
    episode_reward = 0
    # write the training loop
    while True:
        action = agent.select_action(state)
        state, reward, terminated, truncated, _ = env.step(action)
        agent.store_reward(reward)
        episode_reward += reward
        if terminated or truncated:
            break

    loss_ac, loss_cri = agent.update()
    actor_losses.append(loss_ac)
    critic_losses.append(loss_cri)
    rewards_history.append(episode_reward)

    if episode % 20 == 0:
        print(f'Episode:{episode}->\t Reward:{rewards_history[-1]}->\t actor loss:{loss_ac:.6f},\t critic loss:{loss_cri:.6f}')

env.close()

plot_rewards(rewards_history, show_result='PPO agent in HalfCheetah env')
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Episode:0->	 Reward:-751.5592990472816->	 actor loss:-1.111619,	 critic loss:5.658350
# Episode:20->	 Reward:-620.0651066214726->	 actor loss:-0.910665,	 critic loss:5.520086
# Episode:40->	 Reward:-496.2492859504281->	 actor loss:-0.869510,	 critic loss:4.687438
# Episode:60->	 Reward:-509.35996370830776->	 actor loss:-0.841075,	 critic loss:4.490416
# Episode:80->	 Reward:-495.80551178197027->	 actor loss:-0.831679,	 critic loss:5.039297
# Episode:100->	 Reward:-483.5566249064518->	 actor loss:-0.789792,	 critic loss:4.336371
# Episode:120->	 Reward:-317.03371887529164->	 actor loss:-0.808405,	 critic loss:4.110307
# Episode:140->	 Reward:-295.90994926203126->	 actor loss:-0.790971,	 critic loss:5.197663
# Episode:160->	 Reward:-216.89669446954846->	 actor loss:-0.755807,	 critic loss:4.807480
# Episode:180->	 Reward:-248.17797731446734->	 actor loss:-0.714952,	 critic loss:5.224952
# Episode:200->	 Reward:-222.38359107229883->	 actor loss:-0.724497,	 critic loss:4.848142
# Episode:220->	 Reward:-80.72082882291622->	 actor loss:-0.687369,	 critic loss:5.296260
# Episode:240->	 Reward:86.82614354263252->	 actor loss:-0.661031,	 critic loss:5.457130
# Episode:260->	 Reward:73.57873779862364->	 actor loss:-0.668393,	 critic loss:4.792723
# Episode:280->	 Reward:114.84680248137842->	 actor loss:-0.625271,	 critic loss:5.030980
# Episode:300->	 Reward:159.96014601141232->	 actor loss:-0.626172,	 critic loss:4.666735
# Episode:320->	 Reward:296.6543864724813->	 actor loss:-0.583982,	 critic loss:4.815941
# Episode:340->	 Reward:261.9658510415191->	 actor loss:-0.556219,	 critic loss:4.887942
# Episode:360->	 Reward:417.91860956259166->	 actor loss:-0.538664,	 critic loss:4.372439
# Episode:380->	 Reward:338.97744100588034->	 actor loss:-0.526964,	 critic loss:5.563731
# Episode:400->	 Reward:443.1194325198884->	 actor loss:-0.508679,	 critic loss:4.668335
# Episode:420->	 Reward:429.47876658427026->	 actor loss:-0.479720,	 critic loss:4.462692
# Episode:440->	 Reward:426.716141594006->	 actor loss:-0.496998,	 critic loss:5.467858
# Episode:460->	 Reward:575.0503238047671->	 actor loss:-0.460988,	 critic loss:4.922221
# Episode:480->	 Reward:563.2716000515575->	 actor loss:-0.447755,	 critic loss:5.213034
# Episode:500->	 Reward:672.0263409346865->	 actor loss:-0.423119,	 critic loss:4.920733
# Episode:520->	 Reward:529.0147805492227->	 actor loss:-0.452699,	 critic loss:5.335108
# Episode:540->	 Reward:579.9155746715207->	 actor loss:-0.419865,	 critic loss:4.383973
# Episode:560->	 Reward:611.2887673194839->	 actor loss:-0.406874,	 critic loss:3.825145
# Episode:580->	 Reward:684.1492362203458->	 actor loss:-0.401309,	 critic loss:5.098088
# Episode:600->	 Reward:672.819139644752->	 actor loss:-0.403644,	 critic loss:4.710959
# Episode:620->	 Reward:573.627230698592->	 actor loss:-0.375258,	 critic loss:5.453603
# Episode:640->	 Reward:734.1516837070269->	 actor loss:-0.382360,	 critic loss:3.688078
# Episode:660->	 Reward:747.1490197310593->	 actor loss:-0.360022,	 critic loss:6.564232
# Episode:680->	 Reward:655.705088192649->	 actor loss:-0.362145,	 critic loss:5.368531
# Episode:700->	 Reward:742.7671366432751->	 actor loss:-0.379382,	 critic loss:3.979732
# Episode:720->	 Reward:716.6779768745997->	 actor loss:-0.343178,	 critic loss:4.572103
# Episode:740->	 Reward:933.423249644949->	 actor loss:-0.305780,	 critic loss:6.123940
# Episode:760->	 Reward:690.6809033951289->	 actor loss:-0.388595,	 critic loss:5.033012
# Episode:780->	 Reward:925.9707915237744->	 actor loss:-0.323623,	 critic loss:5.624147
# Episode:800->	 Reward:843.5729141316422->	 actor loss:-0.336406,	 critic loss:4.240293
# Episode:820->	 Reward:855.202751297611->	 actor loss:-0.288585,	 critic loss:4.391670
# Episode:840->	 Reward:737.8174459710106->	 actor loss:-0.295325,	 critic loss:4.904890
# Episode:860->	 Reward:903.1458606911162->	 actor loss:-0.278666,	 critic loss:4.593520
# Episode:880->	 Reward:817.3942133474008->	 actor loss:-0.288968,	 critic loss:4.549303
# Episode:900->	 Reward:905.6065971134275->	 actor loss:-0.227484,	 critic loss:4.515234
# Episode:920->	 Reward:973.4112802462319->	 actor loss:-0.278981,	 critic loss:4.935023
# Episode:940->	 Reward:934.1732462941552->	 actor loss:-0.260050,	 critic loss:4.778290
# Episode:960->	 Reward:996.1849208319397->	 actor loss:-0.272481,	 critic loss:5.093863
# Episode:980->	 Reward:855.2400142138989->	 actor loss:-0.258383,	 critic loss:4.805115
# Episode:1000->	 Reward:895.5328055314908->	 actor loss:-0.263211,	 critic loss:5.697044
# Episode:1020->	 Reward:889.0042792106997->	 actor loss:-0.235409,	 critic loss:4.484532
# Episode:1040->	 Reward:-48.28024062880219->	 actor loss:-0.208583,	 critic loss:5.065588
# Episode:1060->	 Reward:875.2927759823872->	 actor loss:-0.259121,	 critic loss:3.979485
# Episode:1080->	 Reward:797.4902827892067->	 actor loss:-0.254735,	 critic loss:4.026030
# Episode:1100->	 Reward:811.2324397243312->	 actor loss:-0.254358,	 critic loss:4.222586
# Episode:1120->	 Reward:850.6206074743479->	 actor loss:-0.268146,	 critic loss:4.408560
# Episode:1140->	 Reward:240.08449997582267->	 actor loss:-0.198369,	 critic loss:4.000863
# Episode:1160->	 Reward:883.9924970868092->	 actor loss:-0.191489,	 critic loss:5.429311
# Episode:1180->	 Reward:919.1212009559052->	 actor loss:-0.221671,	 critic loss:4.512639
# Episode:1200->	 Reward:850.1240672664304->	 actor loss:-0.197303,	 critic loss:5.257060
# Episode:1220->	 Reward:852.6167619470549->	 actor loss:-0.200448,	 critic loss:5.863005
# Episode:1240->	 Reward:917.0253953551367->	 actor loss:-0.219378,	 critic loss:4.751250
# Episode:1260->	 Reward:1056.2595965732912->	 actor loss:-0.165497,	 critic loss:5.220122
# Episode:1280->	 Reward:960.6253189158605->	 actor loss:-0.197454,	 critic loss:5.647734
# Episode:1300->	 Reward:1033.2013849021143->	 actor loss:-0.172230,	 critic loss:5.671604
# Episode:1320->	 Reward:919.0311375004751->	 actor loss:-0.198179,	 critic loss:4.595757
# Episode:1340->	 Reward:991.5507599660573->	 actor loss:-0.176996,	 critic loss:4.508738
# Episode:1360->	 Reward:1007.2394315299398->	 actor loss:-0.200104,	 critic loss:4.035452
# Episode:1380->	 Reward:1010.0249755003713->	 actor loss:-0.167445,	 critic loss:4.537372
# Episode:1400->	 Reward:1016.7951307983737->	 actor loss:-0.191113,	 critic loss:5.733041
# Episode:1420->	 Reward:1098.1544916432401->	 actor loss:-0.165266,	 critic loss:5.530711
# Episode:1440->	 Reward:1026.8912526211227->	 actor loss:-0.172150,	 critic loss:4.376372
# Episode:1460->	 Reward:1056.2961283966492->	 actor loss:-0.169412,	 critic loss:5.429498
# Episode:1480->	 Reward:1080.2671940291116->	 actor loss:-0.182846,	 critic loss:4.894133
# Episode:1500->	 Reward:1089.3548695242985->	 actor loss:-0.166521,	 critic loss:5.180544
# Episode:1520->	 Reward:1052.3668880771063->	 actor loss:-0.151834,	 critic loss:4.938984
# Episode:1540->	 Reward:976.0259309344318->	 actor loss:-0.228652,	 critic loss:4.965932
# Episode:1560->	 Reward:911.3317339039788->	 actor loss:-0.182578,	 critic loss:6.059852
# Episode:1580->	 Reward:1086.5825105738425->	 actor loss:-0.148867,	 critic loss:4.337187
# Episode:1600->	 Reward:1052.7107660929305->	 actor loss:-0.171373,	 critic loss:4.446777
# Episode:1620->	 Reward:1080.9855756366578->	 actor loss:-0.161243,	 critic loss:4.402958
# Episode:1640->	 Reward:940.5661914908355->	 actor loss:-0.220827,	 critic loss:7.234731
# Episode:1660->	 Reward:1138.1543474651664->	 actor loss:-0.183118,	 critic loss:4.828180
# Episode:1680->	 Reward:876.7383156810289->	 actor loss:-0.217564,	 critic loss:4.672047
# Episode:1700->	 Reward:915.2366624115232->	 actor loss:-0.213487,	 critic loss:4.315322
# Episode:1720->	 Reward:410.5502152003643->	 actor loss:-0.195067,	 critic loss:6.188686
# Episode:1740->	 Reward:830.3082738762757->	 actor loss:-0.173577,	 critic loss:5.888255
# Episode:1760->	 Reward:1013.1182279885622->	 actor loss:-0.184274,	 critic loss:4.583349
# Episode:1780->	 Reward:901.8934339877515->	 actor loss:-0.184527,	 critic loss:3.732463
# Episode:1800->	 Reward:809.0069795244971->	 actor loss:-0.208948,	 critic loss:7.427526
# Episode:1820->	 Reward:552.557504983352->	 actor loss:-0.184902,	 critic loss:10.048955
# Episode:1840->	 Reward:860.6265907897237->	 actor loss:-0.168595,	 critic loss:5.446230
# Episode:1860->	 Reward:1002.136768401358->	 actor loss:-0.158454,	 critic loss:4.468764
# Episode:1880->	 Reward:1026.997097418082->	 actor loss:-0.182972,	 critic loss:4.592746
# Episode:1900->	 Reward:975.1388076211415->	 actor loss:-0.185790,	 critic loss:3.841716
# Episode:1920->	 Reward:-43.45752797044021->	 actor loss:-0.182321,	 critic loss:5.006743
# Episode:1940->	 Reward:978.3687351867561->	 actor loss:-0.148183,	 critic loss:3.709612
# Episode:1960->	 Reward:868.0508432277882->	 actor loss:-0.143584,	 critic loss:4.722891
# Episode:1980->	 Reward:818.2634546161696->	 actor loss:-0.164608,	 critic loss:5.941650
# Episode:2000->	 Reward:1009.0021194237811->	 actor loss:-0.120175,	 critic loss:4.078036
# Episode:2020->	 Reward:966.263834790361->	 actor loss:-0.156365,	 critic loss:3.915150
# Episode:2040->	 Reward:875.6770721718665->	 actor loss:-0.145520,	 critic loss:4.738509
# Episode:2060->	 Reward:952.2170340855682->	 actor loss:-0.145346,	 critic loss:4.649765
# Episode:2080->	 Reward:1098.9763311274519->	 actor loss:-0.114512,	 critic loss:5.491282
# Episode:2100->	 Reward:1117.1376362081403->	 actor loss:-0.127526,	 critic loss:3.891357
# Episode:2120->	 Reward:1096.5291696150366->	 actor loss:-0.107457,	 critic loss:4.268429
# Episode:2140->	 Reward:1047.983063031613->	 actor loss:-0.147458,	 critic loss:4.305358
# Episode:2160->	 Reward:960.8634893869987->	 actor loss:-0.140718,	 critic loss:5.069499
# Episode:2180->	 Reward:1088.848839632241->	 actor loss:-0.102636,	 critic loss:4.293619
# Episode:2200->	 Reward:730.1527290749927->	 actor loss:-0.132513,	 critic loss:9.886948
# Episode:2220->	 Reward:1113.907107722625->	 actor loss:-0.123344,	 critic loss:4.665936
# Episode:2240->	 Reward:895.1773624113226->	 actor loss:-0.183970,	 critic loss:5.336330
# Episode:2260->	 Reward:990.667800243326->	 actor loss:-0.143315,	 critic loss:4.061769
# Episode:2280->	 Reward:1024.3391789853977->	 actor loss:-0.145901,	 critic loss:4.841664
# Episode:2300->	 Reward:1055.4973182558726->	 actor loss:-0.129373,	 critic loss:4.310534
# Episode:2320->	 Reward:1203.912597839513->	 actor loss:-0.108224,	 critic loss:5.513670
# Episode:2340->	 Reward:1141.0629918971322->	 actor loss:-0.085444,	 critic loss:5.093464
# Episode:2360->	 Reward:1111.5195230553013->	 actor loss:-0.099590,	 critic loss:4.366209
# Episode:2380->	 Reward:1029.0578203167127->	 actor loss:-0.105596,	 critic loss:4.151891
# Episode:2400->	 Reward:1049.0537445551481->	 actor loss:-0.109462,	 critic loss:5.222284
# Episode:2420->	 Reward:1067.2907135175642->	 actor loss:-0.150281,	 critic loss:3.947388
# Episode:2440->	 Reward:1193.5294175551028->	 actor loss:-0.139267,	 critic loss:4.056691
# Episode:2460->	 Reward:918.7461782162895->	 actor loss:-0.165821,	 critic loss:6.566286
# Episode:2480->	 Reward:905.8892197473793->	 actor loss:-0.155556,	 critic loss:4.442170
# Episode:2500->	 Reward:741.5412146953619->	 actor loss:-0.171833,	 critic loss:7.027904
# Episode:2520->	 Reward:496.3107122045397->	 actor loss:-0.148828,	 critic loss:7.153771
# Episode:2540->	 Reward:741.2928264521565->	 actor loss:-0.165809,	 critic loss:6.954287
# Episode:2560->	 Reward:-51.238838606114776->	 actor loss:-0.192257,	 critic loss:4.592739
# Episode:2580->	 Reward:884.0323009414179->	 actor loss:-0.149742,	 critic loss:4.618621
# Episode:2600->	 Reward:999.5400426919177->	 actor loss:-0.178839,	 critic loss:3.373628
# Episode:2620->	 Reward:1011.4523686748647->	 actor loss:-0.180886,	 critic loss:3.441358
# Episode:2640->	 Reward:471.47598594884454->	 actor loss:-0.171847,	 critic loss:5.357636
# Episode:2660->	 Reward:1036.2059098739846->	 actor loss:-0.146135,	 critic loss:5.173375
# Episode:2680->	 Reward:1052.9411924671404->	 actor loss:-0.181360,	 critic loss:5.298548
# Episode:2700->	 Reward:940.5056820064755->	 actor loss:-0.228681,	 critic loss:4.809042
# Episode:2720->	 Reward:1019.345895687075->	 actor loss:-0.216269,	 critic loss:4.564906
# Episode:2740->	 Reward:1052.1624154126796->	 actor loss:-0.206334,	 critic loss:4.073733
# Episode:2760->	 Reward:857.9970765679338->	 actor loss:-0.223776,	 critic loss:4.016881
# Episode:2780->	 Reward:916.6678171710927->	 actor loss:-0.215875,	 critic loss:4.295806
# Episode:2800->	 Reward:940.6231872575042->	 actor loss:-0.222605,	 critic loss:5.817688
# Episode:2820->	 Reward:974.7887830865245->	 actor loss:-0.189015,	 critic loss:4.422701
# Episode:2840->	 Reward:249.47971801490544->	 actor loss:-0.202920,	 critic loss:8.464754
# Episode:2860->	 Reward:923.0701299718398->	 actor loss:-0.217061,	 critic loss:5.339032
# Episode:2880->	 Reward:926.020270304499->	 actor loss:-0.213305,	 critic loss:5.221612
# Episode:2900->	 Reward:986.0370081128859->	 actor loss:-0.256645,	 critic loss:4.291222
# Episode:2920->	 Reward:904.2988703073393->	 actor loss:-0.225105,	 critic loss:3.953032
# Episode:2940->	 Reward:391.510357980358->	 actor loss:-0.229537,	 critic loss:9.527800
# Episode:2960->	 Reward:949.4632484535628->	 actor loss:-0.205021,	 critic loss:4.085514
# Episode:2980->	 Reward:911.4223759266139->	 actor loss:-0.223567,	 critic loss:5.800767
# <ipython-input-3-ec46d7d2dbdc>:29: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   init_means = np.cumsum(rewards[:init_len]) / (1 + np.arange(init_len))

# %% [markdown]
# # **Evaluating the PPO Agent in the HalfCheetah-v4 Environment**

# %%
# Create environment
# %env MUJOCO_GL=egl
env = gym.make("HalfCheetah-v4", render_mode="rgb_array")
frames = []

state, info = env.reset()
done = False
total_reward = 0

# run the learned PPO agent to evaluate it
#TODO
while True:
    action = agent.select_action(state)
    state, reward, terminated, truncated, info = env.step(action)
    frames.append(env.render())
    total_reward += reward
    if terminated or truncated:
        break


env.close()
print(f"Total Reward: {total_reward}")

# Save frames as a video
video_path = "./agent_evaluation.mp4"
imageio.mimsave(video_path, frames, fps=25)

# Display the video
show_video(video_path)
# Out:
# env: MUJOCO_GL=egl
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Total Reward: 902.940381765213
#     <video width=400 controls>
#           <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
